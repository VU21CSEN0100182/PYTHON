# %% [markdown]
# <a href="https://colab.research.google.com/github/VU21CSEN0100182/PYTHON/blob/main/PYTHON_MATPLOTLIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Matplotlib Pyplot
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 35])
ypoints = np.array([0, 282])
plt.plot(xpoints, ypoints)
plt.show()

# %%
#bargraph
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["VDC","LANG","CLAD","CSEN","MECH","MATH1","MATH2","PHYS"])
y = np.array([81,76,65,92,95,72,82,88])
plt.bar(x,y)
plt.show()

# %%
#piechart
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35,15,15,25])
mylabels = ["DIARY MILK","KITKAT","5 STAR","DARK CHOCOLATE"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
#plotting 
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1, 8])
ypoints=np.array([3, 10])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import numpy as np
x = ["Chocolates", "Bis"]
y = [982,593]
plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["maths","physics","chemistry","english","clad"])
y = np.array([98,65,75,92,63])
plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D","E","F","G"])
y = np.array([15,25,5,28,2,32,45])
plt.bar(x, y, color = "pink")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D","E","F","G"])
y = np.array([15,25,5,28,2,32,45])
plt.bar(x, y, color = "Salmon")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D","E","F","G"])
y = np.array([15,25,5,28,2,32,45])
plt.bar(x, y, color = "magenta")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x, y, color = "violet")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
m=np.array(["A", "B", "C", "D"])
n=np.array([4, 1, 9, 3])
plt.barh(x, y, height =0.46)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([9,2,7,1])
plt.bar(x, y, width =0.62)
plt.show()

# %%
#weight
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35, 25, 25, 15])
fruits=["Apples", "Bananas", "Cherries", "Dates"]
explode=[0.2, 0, 0, 0]
plt.pie(y,labels=fruits,explode=explode)
plt.show()

# %%
#new colours
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35,15,15,25])
fruits= ["Apples", "Bananas", "Cherries", "Dates"]
colors=["red","yellow","pink","brown"]
plt.pie(y,labels=fruits,colors=colors)
plt.show()

# %%
#shadow
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
fruits=["Apples", "Bananas", "Cherries", "Dates"]
explode=[1.3,0,1,2]
plt.pie(y,labels=fruits,explode=explode,shadow=False)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35, 25, 25, 15])
fruits=["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,labels=fruits)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,26,14,25])
fruits=["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,labels = fruits)
plt.legend(title = "Four Fruits:")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,6,2,10])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,25,30,50])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 1, 1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,86])
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.show()
